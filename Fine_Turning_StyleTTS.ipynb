# %%
# !git clone https://github.com/namkuner/Fine_Turning_StyleTTS2_VietNamese.git
# Out:
# Cloning into 'Fine_Turning_StyleTTS2_VietNamese'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 115 (delta 18), reused 114 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (115/115), 26.61 MiB | 13.86 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd Fine_Turning_StyleTTS2_VietNamese
# Out:
# /content/Fine_Turning_StyleTTS2_VietNamese

# %%
# !wget -P Utils/PLBERT/ https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/Utils/PLBERT/step_108000.t7
# !wget -P Utils/JDC/ https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/Utils/JDC/bst.t7
# !wget -P Utils/ASR/ https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/Utils/ASR/epoch_00080.pth
# !wget -P Models/LibriTTS/ https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/Models/LibriTTS/epochs_2nd_00020.pth
# !wget https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/audio_datasets.zip

# !unzip audio_datasets.zip

# %%
# !wget https://huggingface.co/namkuner/Train_StyleTTS2_Vietnamese/resolve/main/audio_datasets.zip
# !unzip audio_datasets.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: audio_datasets/chunk_3/73/99.wav
#    creating: audio_datasets/chunk_3/74/
#   inflating: audio_datasets/chunk_3/74/0.wav
#   inflating: audio_datasets/chunk_3/74/1.wav
#   inflating: audio_datasets/chunk_3/74/10.wav
#   inflating: audio_datasets/chunk_3/74/100.wav
#   inflating: audio_datasets/chunk_3/74/101.wav
#   inflating: audio_datasets/chunk_3/74/102.wav
#   inflating: audio_datasets/chunk_3/74/103.wav
#   inflating: audio_datasets/chunk_3/74/104.wav
#   inflating: audio_datasets/chunk_3/74/105.wav
#   inflating: audio_datasets/chunk_3/74/106.wav
#   inflating: audio_datasets/chunk_3/74/107.wav
#   inflating: audio_datasets/chunk_3/74/108.wav
#   inflating: audio_datasets/chunk_3/74/109.wav
#   inflating: audio_datasets/chunk_3/74/11.wav
#   inflating: audio_datasets/chunk_3/74/110.wav
#   inflating: audio_datasets/chunk_3/74/111.wav
#   inflating: audio_datasets/chunk_3/74/112.wav
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/resemble-ai/monotonic_align.git to /tmp/pip-req-build-3on6tim6
#   Running command git clone --filter=blob:none --quiet https://github.com/resemble-ai/monotonic_align.git /tmp/pip-req-build-3on6tim6
#   Resolved https://github.com/resemble-ai/monotonic_align.git to commit 78b985be210a03d08bc3acc01c4df0442105366f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 91.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd Fine_Turning_StyleTTS2_VietNamese
# Out:
# /content/Fine_Turning_StyleTTS2_VietNamese

# %%
# !python train_finetune.py --config_path ./Configs/config_ft.yml
# Out:
# 2024-10-05 02:49:33.753727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-05 02:49:33.774102: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-05 02:49:33.780100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-05 02:49:33.794588: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
